# %% [markdown]
# # ---กราฟการกระจาย(Scatter)---
# สำหรับแสดงการกระจายของข้อมูลหรือแสดงความสัมพันธ์ระหว่าง 2 ค่า (x, y)
# x = [1,2,3,4,5];
# y = [1,2,5.6,4.5,7];
# sizes = [10,20,12,15,10];
# colors = ["green","pink","red","blue","green"]
# plt.scatter(x,y,s=sizes,c=colors);

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
plt.scatter(x, y)
plt.show()

# %%
size = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300]
color = ["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"]
plt.scatter(x, y, s=size, c=color)
plt.show()

# %%
color = [0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]
plt.scatter(x, y, c=color, cmap='viridis')
plt.colorbar()
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()
